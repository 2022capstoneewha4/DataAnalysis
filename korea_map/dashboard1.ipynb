# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-77a0017c-378a-49d7-ab8f-6e35a07410ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77a0017c-378a-49d7-ab8f-6e35a07410ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
data = pd.read_csv(io.BytesIO(myfile['case.csv']))

# %%
data.head()
# Out:
#    case_id province           city  group                 infection_case  \
# 0        1    Seoul        Guro-gu   True            Guro-gu Call Center
# 1        2    Seoul   Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# 2        3    Seoul   Seongdong-gu   True               Seongdong-gu APT
# 3        4    Seoul      Jongno-gu   True        Jongno Community Center
# 4        5    Seoul  Dongdaemun-gu   True                  Dongan Church
#
#    confirmed   latitude   longitude
# 0         70  37.508163  126.884387
# 1         14   37.63369    126.9165
# 2         13   37.55713    127.0403
# 3         10   37.57681     127.006
# 4          9  37.592888  127.056766

# %%
data
# Out:
#     case_id          province             city  group  \
# 0         1             Seoul          Guro-gu   True
# 1         2             Seoul     Eunpyeong-gu   True
# 2         3             Seoul     Seongdong-gu   True
# 3         4             Seoul        Jongno-gu   True
# 4         5             Seoul    Dongdaemun-gu   True
# ..      ...               ...              ...    ...
# 73       74  Gyeongsangnam-do      Changwon-si   True
# 74       75  Gyeongsangnam-do  Changnyeong-gun   True
# 75       76  Gyeongsangnam-do  from other city   True
# 76       77  Gyeongsangnam-do                -  False
# 77       78           Jeju-do                -  False
#
#                    infection_case  confirmed   latitude   longitude
# 0             Guro-gu Call Center         70  37.508163  126.884387
# 1   Eunpyeong St. Mary's Hospital         14   37.63369    126.9165
# 2                Seongdong-gu APT         13   37.55713    127.0403
# ...

# %%
#latitude가 '-'인 경우 제외하고 자료 가져오기
data = data[data['latitude'] != '-']


#longitude도 확인
data = data[data['longitude'] != '-']

# %%
#null값도 확인
data.isnull().sum()

#데이터테이블 확인
data
# Out:
#     case_id           province             city  group  \
# 0         1              Seoul          Guro-gu   True
# 1         2              Seoul     Eunpyeong-gu   True
# 2         3              Seoul     Seongdong-gu   True
# 3         4              Seoul        Jongno-gu   True
# 4         5              Seoul    Dongdaemun-gu   True
# 5         6              Seoul          Jung-gu   True
# 8         9              Busan       Dongnae-gu   True
# 10       11              Busan       Suyeong-gu   True
# 11       12              Busan      Haeundae-gu   True
# 12       13              Busan           Jin-gu   True
# 15       16              Daegu           Nam-gu   True
# 33       34             Sejong       Boram-dong   True
# 34       35             Sejong       Eojin-dong   True
# 38       39        Gyeonggi-do      Seongnam-si   True
# 40       41        Gyeonggi-do         Suwon-si   True
# 47       48  Chungcheongbuk-do       Goesan-gun   True
# ...

# %%
from folium import plugins

# %%
latitude, longitude = 35.9078, 127.7669 # 대한민국의 좌표
S_korea = folium.Map(location = [latitude, longitude], zoom_start = 8)
S_korea
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
S_korea.add_child(plugins.HeatMap(zip(data['latitude'],
                                      data['longitude'],
                                      data['confirmed']), radius=18))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data['latitude'] = data['latitude'].astype('float')
data['longitude'] = data['longitude'].astype('float')

# %%
S_korea.add_child(plugins.HeatMap(zip(data['latitude'],
                                      data['longitude'],
                                      data['confirmed']), radius=18))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
